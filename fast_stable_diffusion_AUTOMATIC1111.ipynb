# %% [markdown]
# <a href="https://colab.research.google.com/github/geoassul/toni420/blob/master/fast_stable_diffusion_AUTOMATIC1111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Colab Pro notebook from https://github.com/TheLastBen/fast-stable-diffusion. [ComfyUI Colab](https://colab.research.google.com/github/TheLastBen/fast-stable-diffusion/blob/main/fast_stable_diffusion_ComfyUI.ipynb)**

# %%
#@markdown # Connect Google Drive
from google.colab import drive
from IPython.display import clear_output
import ipywidgets as widgets
import os

def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
Shared_Drive = "" #@param {type:"string"}
#@markdown - Leave empty if you're not using a shared drive

print("[0;33mConnecting...")
drive.mount('/content/gdrive')

if Shared_Drive!="" and os.path.exists("/content/gdrive/Shareddrives"):
  mainpth="Shareddrives/"+Shared_Drive
else:
  mainpth="MyDrive"

clear_output()
inf('\u2714 Done','success', '50px')

#@markdown ---
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Install/Update AUTOMATIC1111 repo
from IPython.utils import capture
from IPython.display import clear_output
from subprocess import getoutput
import ipywidgets as widgets
import sys
import fileinput
import os
import time
import base64
import requests
from urllib.request import urlopen, Request
from urllib.parse import urlparse, parse_qs, unquote
from tqdm import tqdm
import six


blsaphemy=base64.b64decode(("ZWJ1aQ==").encode('ascii')).decode('ascii')

if not os.path.exists("/content/gdrive"):
  print('[1;31mGdrive not connected, using temporary colab storage ...')
  time.sleep(4)
  mainpth="MyDrive"
  # !mkdir -p /content/gdrive/$mainpth
  Shared_Drive=""

if Shared_Drive!="" and not os.path.exists("/content/gdrive/Shareddrives"):
  print('[1;31mShared drive not detected, using default MyDrive')
  mainpth="MyDrive"

with capture.capture_output() as cap:
  def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
  fgitclone = "git clone --depth 1"
  # !git clone -q --depth 1 --branch main https://github.com/TheLastBen/diffusers
  # %mkdir -p /content/gdrive/$mainpth/sd
  # %cd /content/gdrive/$mainpth/sd
  # !git clone -q --branch master https://github.com/AUTOMATIC1111/stable-diffusion-w$blsaphemy
  # !mkdir -p /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/cache/
  os.environ['TRANSFORMERS_CACHE']=f"/content/gdrive/{mainpth}/sd/stable-diffusion-w"+blsaphemy+"/cache"
  os.environ['TORCH_HOME'] = f"/content/gdrive/{mainpth}/sd/stable-diffusion-w"+blsaphemy+"/cache"
  # !mkdir -p /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/repositories
  # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-w$blsaphemy-assets /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/repositories/stable-diffusion-webui-assets

with capture.capture_output() as cap:
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/
  # !git reset --hard
  # !git checkout master
  time.sleep(1)
  # !rm webui.sh
  # !git pull
clear_output()
inf('\u2714 Done','success', '50px')

#@markdown ---
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Requirements

print('[1;32mInstalling requirements...')

with capture.capture_output() as cap:
  # !rm -r /usr/local/lib/python3.12/dist-packages/gradio*
  # %cd /content/
  # !wget -q -i https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/Dependencies/A1111.txt
  # !dpkg -i *.deb
  if not os.path.exists('/content/gdrive/'+mainpth+'/sd/stablediffusion'):
    # !tar -C /content/gdrive/$mainpth --zstd -xf sd_mrep.tar.zst
  # !tar -C / --zstd -xf gcolabdeps.tar.zst
  # !rm *.deb | rm *.zst | rm *.txt
  if not os.path.exists('gdrive/'+mainpth+'/sd/libtcmalloc/libtcmalloc_minimal.so.4'):
    # %env CXXFLAGS=-std=c++14
    # !wget -q https://github.com/gperftools/gperftools/releases/download/gperftools-2.5/gperftools-2.5.tar.gz && tar zxf gperftools-2.5.tar.gz && mv gperftools-2.5 gperftools
    # !wget -q https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/Patch
    # %cd /content/gperftools
    # !patch -p1 < /content/Patch
    # !./configure --enable-minimal --enable-libunwind --enable-frame-pointers --enable-dynamic-sized-delete-support --enable-sized-delete --enable-emergency-malloc; make -j4
    # !mkdir -p /content/gdrive/$mainpth/sd/libtcmalloc && cp .libs/libtcmalloc*.so* /content/gdrive/$mainpth/sd/libtcmalloc
    # %env LD_PRELOAD=/content/gdrive/$mainpth/sd/libtcmalloc/libtcmalloc_minimal.so.4
    # %cd /content
    # !rm *.tar.gz Patch && rm -r /content/gperftools
  else:
    # %env LD_PRELOAD=/content/gdrive/$mainpth/sd/libtcmalloc/libtcmalloc_minimal.so.4

  # !pip uninstall jax -y
  # !pip install wandb==0.15.12 pydantic==1.10.2 numpy==1.26 scipy==1.15.3 controlnet_aux --no-deps -qq
  # !pip install diffusers accelerate -U --no-deps -qq
  # !rm -r /usr/local/lib/python3.12/dist-packages/tensorflow*
  os.environ['PYTHONWARNINGS'] = 'ignore'
  # !sed -i 's@text = _formatwarnmsg(msg)@text =\"\"@g' /usr/lib/python3.12/warnings.py
  # !sed -i 's@from pytorch_lightning.loggers.wandb import WandbLogger  # noqa: F401@@g' /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loggers/__init__.py
  # !sed -i 's@from .mailbox import ContextCancelledError@@g' /usr/local/lib/python3.12/dist-packages/wandb/sdk/lib/retry.py
  # !sed -i 's@raise ContextCancelledError("retry timeout")@print("retry timeout")@g' /usr/local/lib/python3.12/dist-packages/wandb/sdk/lib/retry.py
  # !sed -i 's@globalns, localns, set()@globalns, localns, recursive_guard=set()@g' /usr/local/lib/python3.12/dist-packages/pydantic/typing.py

clear_output()
inf('\u2714 Done','success', '50px')

#@markdown ---
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Model Download/Load

import gdown
from gdown.download import get_url_from_gdrive_confirmation
import re

Use_Temp_Storage = True #@param {type:"boolean"}
#@markdown - If not, make sure you have enough space on your gdrive

#@markdown ---

Model_Version = "1.5" #@param ["SDXL", "1.5", "v1.5 Inpainting", "V2.1-768px"]

#@markdown Or
PATH_to_MODEL = "" #@param {type:"string"}
#@markdown - Insert the full path of your custom model or to a folder containing multiple models

#@markdown Or
MODEL_LINK = "https://civitai.com/api/download/models/125771" #@param {type:"string"}


def getsrc(url):
    parsed_url = urlparse(url)
    if parsed_url.netloc == 'civitai.com':
        src='civitai'
    elif parsed_url.netloc == 'drive.google.com':
        src='gdrive'
    elif parsed_url.netloc == 'huggingface.co':
        src='huggingface'
    else:
        src='others'
    return src

src=getsrc(MODEL_LINK)

def get_name(url, gdrive):
    if not gdrive:
        response = requests.get(url, allow_redirects=False)
        if "Location" in response.headers:
            redirected_url = response.headers["Location"]
            quer = parse_qs(urlparse(redirected_url).query)
            if "response-content-disposition" in quer:
                disp_val = quer["response-content-disposition"][0].split(";")
                for vals in disp_val:
                    if vals.strip().startswith("filename="):
                        filenm=unquote(vals.split("=", 1)[1].strip())
                        return filenm.replace("\"","")
    else:
        headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36"}
        lnk="https://drive.google.com/uc?id={id}&export=download".format(id=url[url.find("/d/")+3:url.find("/view")])
        res = requests.session().get(lnk, headers=headers, stream=True, verify=True)
        res = requests.session().get(get_url_from_gdrive_confirmation(res.text), headers=headers, stream=True, verify=True)
        content_disposition = six.moves.urllib_parse.unquote(res.headers["Content-Disposition"])
        filenm = re.search('attachment; filename="(.*?)"', content_disposition).groups()[0]
        return filenm


def dwn(url, dst, msg):
    file_size = None
    req = Request(url, headers={"User-Agent": "torch.hub"})
    u = urlopen(req)
    meta = u.info()
    if hasattr(meta, 'getheaders'):
        content_length = meta.getheaders("Content-Length")
    else:
        content_length = meta.get_all("Content-Length")
    if content_length is not None and len(content_length) > 0:
        file_size = int(content_length[0])

    with tqdm(total=file_size, disable=False, mininterval=0.5,
              bar_format=msg+' |{bar:20}| {percentage:3.0f}%') as pbar:
        with open(dst, "wb") as f:
            while True:
                buffer = u.read(8192)
                if len(buffer) == 0:
                    break
                f.write(buffer)
                pbar.update(len(buffer))
            f.close()


def sdmdls(ver, Use_Temp_Storage):

  if ver=='1.5':
    if Use_Temp_Storage:
      os.makedirs('/content/temp_models', exist_ok=True)
      model='/content/temp_models/v1-5-pruned-emaonly.safetensors'
    else:
      model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-w'+blsaphemy+'/models/Stable-diffusion/v1-5-pruned-emaonly.safetensors'
    link='https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors'
  elif ver=='V2.1-768px':
    if Use_Temp_Storage:
      os.makedirs('/content/temp_models', exist_ok=True)
      model='/content/temp_models/v2-1_768-ema-pruned.safetensors'
    else:
      model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-w'+blsaphemy+'/models/Stable-diffusion/v2-1_768-ema-pruned.safetensors'
    link='https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors'
  elif ver=='v1.5 Inpainting':
    if Use_Temp_Storage:
      os.makedirs('/content/temp_models', exist_ok=True)
      model='/content/temp_models/sd-v1-5-inpainting.ckpt'
    else:
      model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-w'+blsaphemy+'/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'
    link='https://huggingface.co/runwayml/stable-diffusion-inpainting/resolve/main/sd-v1-5-inpainting.ckpt'
  elif ver=='SDXL':
    if Use_Temp_Storage:
      os.makedirs('/content/temp_models', exist_ok=True)
      model='/content/temp_models/sd_xl_base_1.0.safetensors'
    else:
      model='/content/gdrive/'+mainpth+'/sd/stable-diffusion-w'+blsaphemy+'/models/Stable-diffusion/sd_xl_base_1.0.safetensors'
    link='https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors'

  if not os.path.exists(model):
    # !gdown --fuzzy -O $model $link
    if os.path.exists(model):
      clear_output()
      inf('\u2714 Done','success', '50px')
    else:
      inf('\u2718 Something went wrong, try again','danger', "250px")
  else:
      clear_output()
      inf('\u2714 Model already exists','primary', '300px')

  return model


if (PATH_to_MODEL !=''):
  if os.path.exists(str(PATH_to_MODEL)):
    inf('\u2714 Using the trained model.','success', '200px')

  else:
      while not os.path.exists(str(PATH_to_MODEL)):
        inf('\u2718 Wrong path, use the colab file explorer to copy the path : ','danger', "400px")
        PATH_to_MODEL=input()
      if os.path.exists(str(PATH_to_MODEL)):
        inf('\u2714 Using the custom model.','success', '200px')

  model=PATH_to_MODEL

elif MODEL_LINK != "":

      if src=='civitai':
         modelname=get_name(MODEL_LINK, False)
         if Use_Temp_Storage:
            os.makedirs('/content/temp_models', exist_ok=True)
            model=f'/content/temp_models/{modelname}'
         else:
            model=f'/content/gdrive/{mainpth}/sd/stable-diffusion-w{blsaphemy}/models/Stable-diffusion/{modelname}'
         if not os.path.exists(model):
            dwn(MODEL_LINK, model, 'Downloading the custom model')
            clear_output()
         else:
            inf('\u2714 Model already exists','primary', '300px')
      elif src=='gdrive':
         modelname=get_name(MODEL_LINK, True)
         if Use_Temp_Storage:
            os.makedirs('/content/temp_models', exist_ok=True)
            model=f'/content/temp_models/{modelname}'
         else:
            model=f'/content/gdrive/{mainpth}/sd/stable-diffusion-w{blsaphemy}/models/Stable-diffusion/{modelname}'
         if not os.path.exists(model):
            gdown.download(url=MODEL_LINK, output=model, quiet=False, fuzzy=True)
            clear_output()
         else:
            inf('\u2714 Model already exists','primary', '300px')
      else:
         modelname=os.path.basename(MODEL_LINK)
         if Use_Temp_Storage:
            os.makedirs('/content/temp_models', exist_ok=True)
            model=f'/content/temp_models/{modelname}'
         else:
            model=f'/content/gdrive/{mainpth}/sd/stable-diffusion-w{blsaphemy}/models/Stable-diffusion/{modelname}'
         if not os.path.exists(model):
            gdown.download(url=MODEL_LINK, output=model, quiet=False, fuzzy=True)
            clear_output()
         else:
            inf('\u2714 Model already exists','primary', '700px')

      if os.path.exists(model) and os.path.getsize(model) > 1810671599:
        inf('\u2714 Model downloaded, using the custom model.','success', '300px')
      else:
        # !rm model
        inf('\u2718 Wrong link, check that the link is valid','danger', "300px")

else:
  model=sdmdls(Model_Version, Use_Temp_Storage)

#@markdown ---
# Out:
# Button(button_style='success', description='✔ Model downloaded, using the custom model.', disabled=True, layou…

# %%
#@markdown # Download LoRA

LoRA_LINK = "" #@param {type:"string"}

if LoRA_LINK == "":
  inf('\u2714 Nothing to do','primary', '200px')
else:
  os.makedirs('/content/gdrive/'+mainpth+'/sd/stable-diffusion-w'+blsaphemy+'/models/Lora', exist_ok=True)

  src=getsrc(LoRA_LINK)

  if src=='civitai':
      modelname=get_name(LoRA_LINK, False)
      loramodel=f'/content/gdrive/{mainpth}/sd/stable-diffusion-w{blsaphemy}/models/Lora/{modelname}'
      if not os.path.exists(loramodel):
        dwn(LoRA_LINK, loramodel, 'Downloading the LoRA model '+modelname)
        clear_output()
      else:
        inf('\u2714 Model already exists','primary', '200px')
  elif src=='gdrive':
      modelname=get_name(LoRA_LINK, True)
      loramodel=f'/content/gdrive/{mainpth}/sd/stable-diffusion-w{blsaphemy}/models/Lora/{modelname}'
      if not os.path.exists(loramodel):
        gdown.download(url=LoRA_LINK, output=loramodel, quiet=False, fuzzy=True)
        clear_output()
      else:
        inf('\u2714 Model already exists','primary', '200px')
  else:
      modelname=os.path.basename(LoRA_LINK)
      loramodel=f'/content/gdrive/{mainpth}/sd/stable-diffusion-w{blsaphemy}/models/Lora/{modelname}'
      if not os.path.exists(loramodel):
        gdown.download(url=LoRA_LINK, output=loramodel, quiet=False, fuzzy=True)
        clear_output()
      else:
        inf('\u2714 Model already exists','primary', '200px')

  if os.path.exists(loramodel) :
    inf('\u2714 LoRA downloaded','success', '200px')
  else:
    inf('\u2718 Wrong link, check that the link is valid','danger', "300px")

#@markdown ---

# %%
#@markdown # ControlNet
from torch.hub import download_url_to_file
from urllib.parse import urlparse
import re
from subprocess import run

XL_Model = "None" #@param [ "None", "All", "Canny", "Depth", "Sketch", "OpenPose", "Recolor"]

v1_Model = "Softedge" #@param [ "None", "All (21GB)", "Canny", "Depth", "Lineart", "MLSD", "Normal", "OpenPose", "Scribble", "Seg", "ip2p", "Shuffle", "Inpaint", "Softedge", "Lineart_Anime", "Tile", "T2iadapter_Models"]

v2_Model = "None" #@param [ "None", "All", "Canny", "Depth", "HED", "OpenPose", "Scribble"]

#@markdown - Download/update ControlNet extension and its models

def download(url, model_dir):

    filename = os.path.basename(urlparse(url).path)
    pth = os.path.abspath(os.path.join(model_dir, filename))
    if not os.path.exists(pth):
        print('Downloading: '+os.path.basename(url))
        download_url_to_file(url, pth, hash_prefix=None, progress=True)
    else:
      print(f"[1;32mThe model {filename} already exists[0m")


Canny='https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/diffusers_xl_canny_mid.safetensors'
Depth='https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/diffusers_xl_depth_mid.safetensors'
Sketch='https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_sketch_256lora.safetensors'
OpenPose='https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/thibaud_xl_openpose_256lora.safetensors'
Recolor='https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_recolor_128lora.safetensors'


with capture.capture_output() as cap:
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/extensions
  if not os.path.exists('sd-w'+blsaphemy+'-controlnet'):
    # !git clone https://github.com/Mikubill/sd-w$blsaphemy-controlnet.git
    # %cd /content
  else:
    # %cd sd-w$blsaphemy-controlnet
    # !git reset --hard
    # !git pull
    # %cd /content

mdldir='/content/gdrive/'+mainpth+'/sd/stable-diffusion-w'+blsaphemy+'/extensions/sd-w'+blsaphemy+'-controlnet/models'
for filename in os.listdir(mdldir):
  if "_sd14v1" in filename:
    renamed = re.sub("_sd14v1", "-fp16", filename)
    os.rename(os.path.join(mdldir, filename), os.path.join(mdldir, renamed))

# !wget -q -O CN_models.txt https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/CN_models.txt
# !wget -q -O CN_models_v2.txt https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/CN_models_v2.txt
# !wget -q -O CN_models_XL.txt https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/CN_models_XL.txt


with open("CN_models.txt", 'r') as f:
  mdllnk = f.read().splitlines()
with open("CN_models_v2.txt", 'r') as d:
  mdllnk_v2 = d.read().splitlines()
with open("CN_models_XL.txt", 'r') as d:
  mdllnk_XL = d.read().splitlines()

# !rm CN_models.txt CN_models_v2.txt CN_models_XL.txt


if XL_Model == "All":
  for lnk_XL in mdllnk_XL:
      download(lnk_XL, mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

elif XL_Model == "None":
    pass
    clear_output()
    inf('\u2714 Done','success', '50px')

else:
  download(globals()[XL_Model], mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')


Canny='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth'
Depth='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth'
Lineart='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth'
MLSD='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd.pth'
Normal='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae.pth'
OpenPose='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth'
Scribble='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble.pth'
Seg='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth'
ip2p='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth'
Shuffle='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle.pth'
Inpaint='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth'
Softedge='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth'
Lineart_Anime='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime.pth'
Tile='https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth'


with capture.capture_output() as cap:
  cfgnames=[os.path.basename(url).split('.')[0]+'.yaml' for url in mdllnk_v2]
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/extensions/sd-w$blsaphemy-controlnet/models
  for name in cfgnames:
      run(['cp', 'cldm_v21.yaml', name])
  # %cd /content

if v1_Model == "All (21GB)":
  for lnk in mdllnk:
      download(lnk, mdldir)
  clear_output()

elif v1_Model == "T2iadapter_Models":
  mdllnk=list(filter(lambda x: 't2i' in x, mdllnk))
  for lnk in mdllnk:
      download(lnk, mdldir)
  clear_output()

elif v1_Model == "None":
    pass
    clear_output()

else:
  download(globals()[v1_Model], mdldir)
  clear_output()

Canny='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_canny.safetensors'
Depth='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_depth.safetensors'
HED='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_hed.safetensors'
OpenPose='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_openposev2.safetensors'
Scribble='https://huggingface.co/thibaud/controlnet-sd21/resolve/main/control_v11p_sd21_scribble.safetensors'


if v2_Model == "All":
  for lnk_v2 in mdllnk_v2:
      download(lnk_v2, mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

elif v2_Model == "None":
    pass
    clear_output()
    inf('\u2714 Done','success', '50px')

else:
  download(globals()[v2_Model], mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

  #@markdown ---
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Start Stable-Diffusion
from IPython.utils import capture
import time
import sys
import fileinput
from pyngrok import ngrok, conf
import re


Ngrok_token = "" #@param {type:"string"}

#@markdown - Input your ngrok token if you want to use ngrok server

User = "" #@param {type:"string"}
Password= "" #@param {type:"string"}
#@markdown - Add credentials to your Gradio interface (optional)

auth=f"--gradio-auth {User}:{Password}"
if User =="" or Password=="":
  auth=""


with capture.capture_output() as cap:
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/modules/
  # !wget -q -O extras.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-w$blsaphemy/master/modules/extras.py
  # !wget -q -O sd_models.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-w$blsaphemy/master/modules/sd_models.py
  # !wget -q -O /usr/local/lib/python3.12/dist-packages/gradio/blocks.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/blocks.py
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/

  # !sed -i 's@shared.opts.data\["sd_model_checkpoint"] = checkpoint_info.title@shared.opts.data\["sd_model_checkpoint"] = checkpoint_info.title;model.half()@' /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/modules/sd_models.py
  #!sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/webui.py
  # !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/modules/extras.py

  # !sed -i 's@possible_sd_paths =.*@possible_sd_paths = [\"/content/gdrive/{mainpth}/sd/stablediffusion\"]@' /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/modules/paths.py
  # !sed -i 's@\.\.\/@src/@g' /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/modules/paths.py
  # !sed -i 's@src/generative-models@generative-models@g' /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/modules/paths.py

  # !sed -i 's@print(\"No module.*@@' /content/gdrive/$mainpth/sd/stablediffusion/ldm/modules/diffusionmodules/model.py
  # !sed -i 's@\["sd_model_checkpoint"\]@\["sd_model_checkpoint", "sd_vae", "CLIP_stop_at_last_layers", "inpainting_mask_weight", "initial_noise_multiplier"\]@g' /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/modules/shared.py
  # !sed -i "s@res = self.CLIPTextModel_from_pretrained(None@res = self.CLIPTextModel_from_pretrained(pretrained_model_name_or_path@" /content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/sd_disable_initialization.py

share=''
if Ngrok_token!="":
  ngrok.kill()
  srv=ngrok.connect(7860, pyngrok_config=conf.PyngrokConfig(auth_token=Ngrok_token) , bind_tls=True).public_url

  for line in fileinput.input('/usr/local/lib/python3.12/dist-packages/gradio/blocks.py', inplace=True):
    if line.strip().startswith('self.server_name ='):
        line = f'            self.server_name = "{srv[8:]}"\n'
    if line.strip().startswith('self.protocol = "https"'):
        line = '            self.protocol = "https"\n'
    if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
        line = ''
    if line.strip().startswith('else "http"'):
        line = ''
    sys.stdout.write(line)
else:
  share='--share'

ckptdir=''
if os.path.exists('/content/temp_models'):
  ckptdir='--ckpt-dir /content/temp_models'

try:
  model
  if os.path.isfile(model):
    # !python /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt "$model" --xformers $auth --disable-console-progressbars --skip-version-check $ckptdir
  else:
    # !python /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt-dir "$model" --xformers $auth --disable-console-progressbars --skip-version-check
except:
   # !python /content/gdrive/$mainpth/sd/stable-diffusion-w$blsaphemy/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae --xformers $auth --disable-console-progressbars --skip-version-check $ckptdir
# Out:
# ControlNet preprocessor location: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads
# 2026-02-18 23:24:02,933 - ControlNet - INFO - ControlNet v1.1.455
# Loading weights [e8d456c42e] from /content/temp_models/toonyou_beta6.safetensors
# Creating model from config: /content/gdrive/MyDrive/sd/stable-diffusion-webui/configs/v1-inference.yaml
# 2026-02-18 23:24:04,186 - ControlNet - INFO - ControlNet UI callback registered.
# Running on public URL: https://772a081bc3de25cb06.gradio.live
# ✔ Connected
# Startup time: 20.2s (import torch: 6.0s, import gradio: 4.2s, setup paths: 2.3s, initialize shared: 0.3s, other imports: 1.0s, list SD models: 1.4s, load scripts: 1.9s, initialize extra networks: 0.3s, create ui: 1.5s, gradio launch: 0.6s, add APIs: 0.5s).
# Applying attention optimization: xformers... done.
# Model loaded in 6.2s (load weights from disk: 0.4s, create model: 1.8s, apply weights to model: 3.5s, calculate empty prompt: 0.3s).
# 2026-02-18 23:28:53,023 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:28:53,533 - ControlNet - INFO - Loading model: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:29:00,700 - ControlNet - INFO - Loaded state_dict from [/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_v11p_sd15_softedge.pth]
# 2026-02-18 23:29:00,701 - ControlNet - INFO - controlnet_default_config
# 2026-02-18 23:29:04,413 - ControlNet - INFO - ControlNet model control_v11p_sd15_softedge [a8575a2a](ControlModelType.ControlNet) loaded.
# *** Error running process: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py
#     Traceback (most recent call last):
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/scripts.py", line 832, in process
#         script.process(p, *script_args)
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 1228, in process
#         self.controlnet_hack(p)
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 1213, in controlnet_hack
#         self.controlnet_main_entry(p)
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 941, in controlnet_main_entry
#         controls, hr_controls, additional_maps = get_control(
#                                                  ^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 206, in get_control
#         input_image, resize_mode = Script.choose_input_image(p, unit, idx)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 743, in choose_input_image
#         raise ValueError("controlnet is enabled but no input image is given")
#     ValueError: controlnet is enabled but no input image is given
#
# ---
# *** Error completing request
# *** Arguments: ('task(stqn2wjd7263tkh)', <gradio.routes.Request object at 0x7b6019ae8710>, 0, '(masterpiece, best quality), cartoon style, disney animation style, vibrant colors, A woman holding a microphone giving a speech at a graduation ceremony, people wearing graduation gowns and caps in background, clapping hands, indoors, stage lights\n', 'photorealistic, 3d, realistic, ugly, blurry, messy drawing, text, watermark\n', [], None, None, None, None, None, None, None, 4, 0, 1, 1, 1, 7, 1.5, 0.46, 0.0, 768, 512, 1, 0, 0, 32, 0, '/content/input_frames', '/content/output_frames_v2', '', [], False, [], '', 'from dir', None, 0, False, 1, 0.5, 4, 0, 0.5, 2, 20, 'DPM++ 2M', 'Automatic', False, '', 0.8, -1, False, -1, 0, 0, 0, ControlNetUnit(is_ui=True, input_mode=<InputMode.SIMPLE: 'simple'>, batch_images='/content/input_frames', output_dir='/content/output_frames_v2', loopback=False, enabled=True, module='softedge_pidinet', model='control_v11p_sd15_softedge [a8575a2a]', weight=1.0, image=None, resize_mode=<ResizeMode.INNER_FIT: 'Crop and Resize'>, low_vram=False, processor_res=512, threshold_a=0.5, threshold_b=0.5, guidance_start=0.0, guidance_end=1.0, pixel_perfect=True, control_mode=<ControlMode.BALANCED: 'Balanced'>, inpaint_crop_input_image=True, hr_option=<HiResFixOption.BOTH: 'Both'>, save_detected_map=True, advanced_weighting=None, effective_region_mask=None, pulid_mode=<PuLIDMode.FIDELITY: 'Fidelity'>, union_control_type=<ControlNetUnionControlType.SOFT_EDGE: 'Soft Edge'>, ipadapter_input=None, mask=None, batch_mask_dir=None, animatediff_batch=False, batch_modifiers=[], batch_image_files=[], batch_keyframe_idx=None), ControlNetUnit(is_ui=True, input_mode=<InputMode.SIMPLE: 'simple'>, batch_images='/content/input_frames', output_dir='/content/output_frames_v2', loopback=False, enabled=False, module='none', model='None', weight=1.0, image=None, resize_mode=<ResizeMode.INNER_FIT: 'Crop and Resize'>, low_vram=False, processor_res=-1, threshold_a=-1.0, threshold_b=-1.0, guidance_start=0.0, guidance_end=1.0, pixel_perfect=False, control_mode=<ControlMode.BALANCED: 'Balanced'>, inpaint_crop_input_image=True, hr_option=<HiResFixOption.BOTH: 'Both'>, save_detected_map=True, advanced_weighting=None, effective_region_mask=None, pulid_mode=<PuLIDMode.FIDELITY: 'Fidelity'>, union_control_type=<ControlNetUnionControlType.UNKNOWN: 'Unknown'>, ipadapter_input=None, mask=None, batch_mask_dir=None, animatediff_batch=False, batch_modifiers=[], batch_image_files=[], batch_keyframe_idx=None), ControlNetUnit(is_ui=True, input_mode=<InputMode.SIMPLE: 'simple'>, batch_images='/content/input_frames', output_dir='/content/output_frames_v2', loopback=False, enabled=False, module='none', model='None', weight=1.0, image=None, resize_mode=<ResizeMode.INNER_FIT: 'Crop and Resize'>, low_vram=False, processor_res=-1, threshold_a=-1.0, threshold_b=-1.0, guidance_start=0.0, guidance_end=1.0, pixel_perfect=False, control_mode=<ControlMode.BALANCED: 'Balanced'>, inpaint_crop_input_image=True, hr_option=<HiResFixOption.BOTH: 'Both'>, save_detected_map=True, advanced_weighting=None, effective_region_mask=None, pulid_mode=<PuLIDMode.FIDELITY: 'Fidelity'>, union_control_type=<ControlNetUnionControlType.UNKNOWN: 'Unknown'>, ipadapter_input=None, mask=None, batch_mask_dir=None, animatediff_batch=False, batch_modifiers=[], batch_image_files=[], batch_keyframe_idx=None), '* `CFG Scale` should be 2 or lower.', True, True, '', '', True, 50, True, 1, 0, False, 4, 0.5, 'Linear', 'None', '<p style="margin-bottom:0.75em">Recommended settings: Sampling Steps: 80-100, Sampler: Euler a, Denoising strength: 0.8</p>', 128, 8, ['left', 'right', 'up', 'down'], 1, 0.05, 128, 4, 0, ['left', 'right', 'up', 'down'], False, False, 'positive', 'comma', 0, False, False, 'start', '', '<p style="margin-bottom:0.75em">Will upscale the image by the selected scale factor; use width and height sliders to set tile size</p>', 64, 0, 2, 1, '', [], 0, '', [], 0, '', [], True, False, False, False, ...
#     Traceback (most recent call last):
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/call_queue.py", line 74, in f
#         res = list(func(*args, **kwargs))
#                    ^^^^^^^^^^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/call_queue.py", line 53, in f
#         res = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/call_queue.py", line 37, in f
#         res = func(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/img2img.py", line 242, in img2img
#         processed = process_images(p)
#                     ^^^^^^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/processing.py", line 847, in process_images
#         res = process_images_inner(p)
#               ^^^^^^^^^^^^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/batch_hijack.py", line 59, in processing_process_images_hijack
#         return getattr(processing, '__controlnet_original_process_images_inner')(p, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/processing.py", line 921, in process_images_inner
#         p.init(p.all_prompts, p.all_seeds, p.all_subseeds)
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/processing.py", line 1677, in init
#         image = images.flatten(img, opts.img2img_background_color)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/images.py", line 844, in flatten
#         if img.mode == "RGBA":
#            ^^^^^^^^
#     AttributeError: 'NoneType' object has no attribute 'mode'
#
# ---
# Will process 148 images, creating 1 new images for each.
# 2026-02-18 23:30:49,261 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:30:49,262 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:30:49,266 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:30:49,267 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:30:49,383 - ControlNet - INFO - Loaded state_dict from [/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/pidinet/table5_pidinet.pth]
# 2026-02-18 23:30:49,942 - ControlNet - INFO - ControlNet Hooked - Time = 0.6837995052337646
# 100% 10/10 [00:03<00:00,  2.63it/s]
# 2026-02-18 23:30:55,959 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:30:55,960 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:30:55,965 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:30:55,965 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:30:56,116 - ControlNet - INFO - ControlNet Hooked - Time = 0.16250371932983398
# 100% 10/10 [00:03<00:00,  3.05it/s]
# 2026-02-18 23:31:01,147 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:01,147 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:01,149 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:01,149 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:01,273 - ControlNet - INFO - ControlNet Hooked - Time = 0.13003134727478027
# 100% 10/10 [00:03<00:00,  3.05it/s]
# 2026-02-18 23:31:06,295 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:06,295 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:06,297 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:06,297 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:06,421 - ControlNet - INFO - ControlNet Hooked - Time = 0.12859487533569336
# 100% 10/10 [00:03<00:00,  3.02it/s]
# 2026-02-18 23:31:11,651 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:11,652 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:11,654 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:11,654 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:11,778 - ControlNet - INFO - ControlNet Hooked - Time = 0.1301860809326172
# 100% 10/10 [00:03<00:00,  3.01it/s]
# 2026-02-18 23:31:16,877 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:16,877 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:16,879 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:16,879 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:17,011 - ControlNet - INFO - ControlNet Hooked - Time = 0.13769865036010742
# 100% 10/10 [00:03<00:00,  2.98it/s]
# 2026-02-18 23:31:22,309 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:22,309 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:22,312 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:22,312 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:22,456 - ControlNet - INFO - ControlNet Hooked - Time = 0.15462660789489746
# 100% 10/10 [00:03<00:00,  2.94it/s]
# 2026-02-18 23:31:27,656 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:27,656 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:27,658 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:27,658 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:27,779 - ControlNet - INFO - ControlNet Hooked - Time = 0.12670207023620605
# 100% 10/10 [00:03<00:00,  2.93it/s]
# 2026-02-18 23:31:32,988 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:32,988 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:32,990 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:32,990 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:33,112 - ControlNet - INFO - ControlNet Hooked - Time = 0.12797856330871582
# 100% 10/10 [00:03<00:00,  2.92it/s]
# 2026-02-18 23:31:38,503 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:38,503 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:38,506 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:38,506 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:38,638 - ControlNet - INFO - ControlNet Hooked - Time = 0.14062118530273438
# 100% 10/10 [00:03<00:00,  2.91it/s]
# 2026-02-18 23:31:43,857 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:43,857 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:43,859 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:43,859 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:43,988 - ControlNet - INFO - ControlNet Hooked - Time = 0.13441753387451172
# 100% 10/10 [00:03<00:00,  2.90it/s]
# 2026-02-18 23:31:49,404 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:49,404 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:49,406 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:49,406 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:49,550 - ControlNet - INFO - ControlNet Hooked - Time = 0.15099024772644043
# 100% 10/10 [00:03<00:00,  2.89it/s]
# 2026-02-18 23:31:54,828 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:31:54,828 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:31:54,830 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:31:54,830 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:31:54,951 - ControlNet - INFO - ControlNet Hooked - Time = 0.1258251667022705
# 100% 10/10 [00:03<00:00,  2.87it/s]
# 2026-02-18 23:32:00,242 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:00,243 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:00,245 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:00,245 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:00,367 - ControlNet - INFO - ControlNet Hooked - Time = 0.12790966033935547
# 100% 10/10 [00:03<00:00,  2.86it/s]
# 2026-02-18 23:32:05,792 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:05,792 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:05,794 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:05,794 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:05,915 - ControlNet - INFO - ControlNet Hooked - Time = 0.12634038925170898
# 100% 10/10 [00:03<00:00,  2.86it/s]
# 2026-02-18 23:32:11,230 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:11,230 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:11,232 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:11,232 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:11,366 - ControlNet - INFO - ControlNet Hooked - Time = 0.1399385929107666
# 100% 10/10 [00:03<00:00,  2.84it/s]
# 2026-02-18 23:32:16,856 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:16,857 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:16,859 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:16,859 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:17,007 - ControlNet - INFO - ControlNet Hooked - Time = 0.1561295986175537
# 100% 10/10 [00:03<00:00,  2.83it/s]
# 2026-02-18 23:32:22,380 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:22,380 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:22,382 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:22,383 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:22,507 - ControlNet - INFO - ControlNet Hooked - Time = 0.13004803657531738
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:32:27,924 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:27,924 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:27,926 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:27,926 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:28,057 - ControlNet - INFO - ControlNet Hooked - Time = 0.1363687515258789
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:32:33,513 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:33,513 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:33,515 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:33,516 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:33,642 - ControlNet - INFO - ControlNet Hooked - Time = 0.1320943832397461
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:32:39,146 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:39,146 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:39,148 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:39,148 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:39,273 - ControlNet - INFO - ControlNet Hooked - Time = 0.13016176223754883
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:32:44,985 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:44,985 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:44,988 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:44,988 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:45,133 - ControlNet - INFO - ControlNet Hooked - Time = 0.15341734886169434
# 100% 10/10 [00:03<00:00,  2.69it/s]
# 2026-02-18 23:32:50,767 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:50,768 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:50,770 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:50,770 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:50,894 - ControlNet - INFO - ControlNet Hooked - Time = 0.12943553924560547
# 100% 10/10 [00:03<00:00,  2.66it/s]
# 2026-02-18 23:32:56,708 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:32:56,708 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:32:56,711 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:32:56,711 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:32:56,863 - ControlNet - INFO - ControlNet Hooked - Time = 0.16035079956054688
# 100% 10/10 [00:03<00:00,  2.66it/s]
# 2026-02-18 23:33:02,596 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:02,596 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:02,598 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:02,598 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:02,722 - ControlNet - INFO - ControlNet Hooked - Time = 0.12974023818969727
# 100% 10/10 [00:03<00:00,  2.70it/s]
# 2026-02-18 23:33:08,326 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:08,327 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:08,329 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:08,329 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:08,453 - ControlNet - INFO - ControlNet Hooked - Time = 0.1297740936279297
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:33:13,996 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:13,996 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:13,999 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:13,999 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:14,130 - ControlNet - INFO - ControlNet Hooked - Time = 0.13681483268737793
# 100% 10/10 [00:03<00:00,  2.75it/s]
# 2026-02-18 23:33:19,630 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:19,630 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:19,632 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:19,632 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:19,760 - ControlNet - INFO - ControlNet Hooked - Time = 0.13331341743469238
# 100% 10/10 [00:03<00:00,  2.77it/s]
# 2026-02-18 23:33:25,376 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:25,376 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:25,378 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:25,379 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:25,531 - ControlNet - INFO - ControlNet Hooked - Time = 0.16031980514526367
# 100% 10/10 [00:03<00:00,  2.80it/s]
# 2026-02-18 23:33:30,985 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:30,985 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:30,987 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:30,987 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:31,111 - ControlNet - INFO - ControlNet Hooked - Time = 0.1294107437133789
# 100% 10/10 [00:03<00:00,  2.80it/s]
# 2026-02-18 23:33:36,546 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:36,546 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:36,549 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:36,549 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:36,700 - ControlNet - INFO - ControlNet Hooked - Time = 0.15911102294921875
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:33:42,192 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:42,192 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:42,194 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:42,194 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:42,325 - ControlNet - INFO - ControlNet Hooked - Time = 0.13941454887390137
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:33:47,769 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:47,769 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:47,771 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:47,771 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:47,896 - ControlNet - INFO - ControlNet Hooked - Time = 0.13041186332702637
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:33:53,535 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:53,536 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:53,538 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:53,538 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:53,669 - ControlNet - INFO - ControlNet Hooked - Time = 0.13672876358032227
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:33:59,139 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:33:59,139 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:33:59,142 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:33:59,142 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:33:59,268 - ControlNet - INFO - ControlNet Hooked - Time = 0.1320791244506836
# 100% 10/10 [00:03<00:00,  2.75it/s]
# 2026-02-18 23:34:04,906 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:04,906 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:04,909 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:04,909 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:05,059 - ControlNet - INFO - ControlNet Hooked - Time = 0.16059517860412598
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:34:10,573 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:10,573 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:10,575 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:10,576 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:10,700 - ControlNet - INFO - ControlNet Hooked - Time = 0.12974238395690918
# 100% 10/10 [00:03<00:00,  2.75it/s]
# 2026-02-18 23:34:16,239 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:16,239 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:16,242 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:16,242 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:16,370 - ControlNet - INFO - ControlNet Hooked - Time = 0.1340503692626953
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:34:21,896 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:21,896 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:21,898 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:21,898 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:22,026 - ControlNet - INFO - ControlNet Hooked - Time = 0.13287663459777832
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:34:27,590 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:27,590 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:27,592 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:27,592 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:27,723 - ControlNet - INFO - ControlNet Hooked - Time = 0.136399507522583
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:34:33,417 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:33,417 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:33,419 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:33,419 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:33,581 - ControlNet - INFO - ControlNet Hooked - Time = 0.1713275909423828
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:34:39,117 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:39,118 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:39,120 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:39,120 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:39,255 - ControlNet - INFO - ControlNet Hooked - Time = 0.14011621475219727
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:34:44,853 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:44,854 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:44,856 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:44,856 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:44,999 - ControlNet - INFO - ControlNet Hooked - Time = 0.15086817741394043
# 100% 10/10 [00:03<00:00,  2.77it/s]
# 2026-02-18 23:34:50,483 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:50,483 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:50,485 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:50,485 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:50,610 - ControlNet - INFO - ControlNet Hooked - Time = 0.13058996200561523
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:34:56,046 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:34:56,046 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:34:56,048 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:34:56,048 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:34:56,176 - ControlNet - INFO - ControlNet Hooked - Time = 0.1323559284210205
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:35:01,626 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:01,626 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:01,628 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:01,628 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:01,755 - ControlNet - INFO - ControlNet Hooked - Time = 0.1316220760345459
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:35:07,203 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:07,204 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:07,206 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:07,206 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:07,334 - ControlNet - INFO - ControlNet Hooked - Time = 0.13404440879821777
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:35:12,921 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:12,921 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:12,923 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:12,923 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:13,076 - ControlNet - INFO - ControlNet Hooked - Time = 0.16022348403930664
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:35:18,571 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:18,571 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:18,573 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:18,573 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:18,713 - ControlNet - INFO - ControlNet Hooked - Time = 0.1456587314605713
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:35:24,216 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:24,216 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:24,218 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:24,218 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:24,378 - ControlNet - INFO - ControlNet Hooked - Time = 0.16546177864074707
# 100% 10/10 [00:03<00:00,  2.71it/s]
# 2026-02-18 23:35:29,965 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:29,965 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:29,968 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:29,968 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:30,094 - ControlNet - INFO - ControlNet Hooked - Time = 0.13235735893249512
# 100% 10/10 [00:03<00:00,  2.69it/s]
# 2026-02-18 23:35:35,734 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:35,734 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:35,736 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:35,736 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:35,865 - ControlNet - INFO - ControlNet Hooked - Time = 0.13400864601135254
# 100% 10/10 [00:03<00:00,  2.66it/s]
# 2026-02-18 23:35:41,643 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:41,643 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:41,645 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:41,646 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:41,781 - ControlNet - INFO - ControlNet Hooked - Time = 0.14099574089050293
# 100% 10/10 [00:03<00:00,  2.68it/s]
# 2026-02-18 23:35:47,407 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:47,407 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:47,409 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:47,409 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:47,539 - ControlNet - INFO - ControlNet Hooked - Time = 0.1349196434020996
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:35:53,253 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:53,253 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:53,256 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:53,256 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:53,409 - ControlNet - INFO - ControlNet Hooked - Time = 0.16238689422607422
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:35:58,971 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:35:58,971 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:35:58,973 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:35:58,973 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:35:59,099 - ControlNet - INFO - ControlNet Hooked - Time = 0.1318652629852295
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:36:04,583 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:04,583 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:04,586 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:04,586 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:04,722 - ControlNet - INFO - ControlNet Hooked - Time = 0.14250850677490234
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:36:10,210 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:10,211 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:10,213 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:10,213 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:10,343 - ControlNet - INFO - ControlNet Hooked - Time = 0.13587522506713867
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:36:15,782 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:15,783 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:15,785 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:15,785 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:15,912 - ControlNet - INFO - ControlNet Hooked - Time = 0.13295769691467285
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:36:21,490 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:21,491 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:21,493 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:21,493 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:21,646 - ControlNet - INFO - ControlNet Hooked - Time = 0.16148638725280762
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:36:27,126 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:27,126 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:27,128 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:27,129 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:27,255 - ControlNet - INFO - ControlNet Hooked - Time = 0.1322634220123291
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:36:32,858 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:32,859 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:32,861 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:32,861 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:33,008 - ControlNet - INFO - ControlNet Hooked - Time = 0.15469717979431152
# 100% 10/10 [00:03<00:00,  2.77it/s]
# 2026-02-18 23:36:38,499 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:38,499 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:38,502 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:38,502 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:38,627 - ControlNet - INFO - ControlNet Hooked - Time = 0.13074398040771484
# 100% 10/10 [00:03<00:00,  2.77it/s]
# 2026-02-18 23:36:44,086 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:44,087 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:44,089 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:44,089 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:44,218 - ControlNet - INFO - ControlNet Hooked - Time = 0.13483262062072754
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:36:49,733 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:49,734 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:49,736 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:49,736 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:49,863 - ControlNet - INFO - ControlNet Hooked - Time = 0.13267207145690918
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:36:55,396 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:36:55,396 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:36:55,399 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:36:55,399 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:36:55,524 - ControlNet - INFO - ControlNet Hooked - Time = 0.13123226165771484
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:37:01,208 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:01,208 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:01,210 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:01,213 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:01,377 - ControlNet - INFO - ControlNet Hooked - Time = 0.17721295356750488
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:37:06,906 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:06,907 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:06,909 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:06,909 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:07,038 - ControlNet - INFO - ControlNet Hooked - Time = 0.13440608978271484
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:37:12,543 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:12,543 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:12,545 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:12,545 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:12,674 - ControlNet - INFO - ControlNet Hooked - Time = 0.13415002822875977
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:37:18,214 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:18,214 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:18,216 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:18,217 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:18,345 - ControlNet - INFO - ControlNet Hooked - Time = 0.1336960792541504
# 100% 10/10 [00:03<00:00,  2.77it/s]
# 2026-02-18 23:37:23,795 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:23,795 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:23,798 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:23,798 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:23,922 - ControlNet - INFO - ControlNet Hooked - Time = 0.12987923622131348
# 100% 10/10 [00:03<00:00,  2.75it/s]
# 2026-02-18 23:37:29,628 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:29,628 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:29,631 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:29,631 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:29,767 - ControlNet - INFO - ControlNet Hooked - Time = 0.14524245262145996
# 100% 10/10 [00:03<00:00,  2.77it/s]
# 2026-02-18 23:37:35,229 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:35,229 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:35,231 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:35,231 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:35,357 - ControlNet - INFO - ControlNet Hooked - Time = 0.13268685340881348
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:37:40,955 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:40,955 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:40,958 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:40,958 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:41,111 - ControlNet - INFO - ControlNet Hooked - Time = 0.16144037246704102
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:37:46,585 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:46,585 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:46,587 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:46,587 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:46,713 - ControlNet - INFO - ControlNet Hooked - Time = 0.1309349536895752
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:37:52,146 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:52,146 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:52,148 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:52,148 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:52,274 - ControlNet - INFO - ControlNet Hooked - Time = 0.1308736801147461
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:37:57,712 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:37:57,712 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:37:57,714 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:37:57,714 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:37:57,847 - ControlNet - INFO - ControlNet Hooked - Time = 0.1383378505706787
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:38:03,279 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:38:03,279 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:38:03,282 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:38:03,282 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:38:03,406 - ControlNet - INFO - ControlNet Hooked - Time = 0.1296999454498291
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:38:08,990 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:38:08,991 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:38:08,993 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:38:08,994 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:38:09,142 - ControlNet - INFO - ControlNet Hooked - Time = 0.15628361701965332
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:38:14,637 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:38:14,637 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# ...
# 2026-02-18 23:41:56,200 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:41:56,200 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:41:56,329 - ControlNet - INFO - ControlNet Hooked - Time = 0.13493013381958008
# 100% 10/10 [00:03<00:00,  2.77it/s]
# 2026-02-18 23:42:01,807 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:01,808 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:01,810 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:01,810 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:01,937 - ControlNet - INFO - ControlNet Hooked - Time = 0.13326358795166016
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:42:07,366 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:07,366 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:07,368 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:07,368 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:07,492 - ControlNet - INFO - ControlNet Hooked - Time = 0.12897014617919922
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:42:13,064 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:13,064 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:13,067 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:13,067 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:13,216 - ControlNet - INFO - ControlNet Hooked - Time = 0.15719151496887207
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:42:18,663 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:18,664 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:18,666 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:18,666 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:18,789 - ControlNet - INFO - ControlNet Hooked - Time = 0.12890839576721191
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:42:24,392 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:24,393 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:24,395 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:24,395 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:24,538 - ControlNet - INFO - ControlNet Hooked - Time = 0.15093159675598145
# 100% 10/10 [00:03<00:00,  2.77it/s]
# 2026-02-18 23:42:30,007 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:30,007 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:30,010 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:30,010 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:30,134 - ControlNet - INFO - ControlNet Hooked - Time = 0.1302330493927002
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:42:35,617 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:35,617 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:35,619 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:35,619 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:35,744 - ControlNet - INFO - ControlNet Hooked - Time = 0.1300058364868164
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:42:41,279 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:41,280 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:41,282 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:41,282 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:41,408 - ControlNet - INFO - ControlNet Hooked - Time = 0.1322345733642578
# 100% 10/10 [00:03<00:00,  2.71it/s]
# 2026-02-18 23:42:46,949 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:46,949 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:46,951 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:46,951 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:47,076 - ControlNet - INFO - ControlNet Hooked - Time = 0.130021333694458
# 100% 10/10 [00:03<00:00,  2.70it/s]
# 2026-02-18 23:42:52,788 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:52,788 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:52,791 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:52,791 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:52,934 - ControlNet - INFO - ControlNet Hooked - Time = 0.15082311630249023
# 100% 10/10 [00:03<00:00,  2.67it/s]
# 2026-02-18 23:42:58,582 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:42:58,583 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:42:58,585 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:42:58,585 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:42:58,711 - ControlNet - INFO - ControlNet Hooked - Time = 0.13194799423217773
# 100% 10/10 [00:03<00:00,  2.66it/s]
# 2026-02-18 23:43:04,520 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:04,520 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:04,523 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:04,523 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:04,674 - ControlNet - INFO - ControlNet Hooked - Time = 0.15873241424560547
# 100% 10/10 [00:03<00:00,  2.67it/s]
# 2026-02-18 23:43:10,329 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:10,329 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:10,331 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:10,331 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:10,458 - ControlNet - INFO - ControlNet Hooked - Time = 0.13218283653259277
# 100% 10/10 [00:03<00:00,  2.72it/s]
# 2026-02-18 23:43:16,004 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:16,004 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:16,006 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:16,006 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:16,132 - ControlNet - INFO - ControlNet Hooked - Time = 0.13144183158874512
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:43:21,658 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:21,658 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:21,660 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:21,660 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:21,785 - ControlNet - INFO - ControlNet Hooked - Time = 0.12965822219848633
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:43:27,275 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:27,275 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:27,277 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:27,277 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:27,401 - ControlNet - INFO - ControlNet Hooked - Time = 0.12911558151245117
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:43:33,013 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:33,013 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:33,016 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:33,016 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:33,164 - ControlNet - INFO - ControlNet Hooked - Time = 0.15767526626586914
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:43:38,615 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:38,616 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:38,618 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:38,618 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:38,743 - ControlNet - INFO - ControlNet Hooked - Time = 0.13022923469543457
# 100% 10/10 [00:03<00:00,  2.80it/s]
# 2026-02-18 23:43:44,172 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:44,172 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:44,174 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:44,174 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:44,299 - ControlNet - INFO - ControlNet Hooked - Time = 0.12990880012512207
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:43:49,728 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:49,728 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:49,730 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:49,730 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:49,853 - ControlNet - INFO - ControlNet Hooked - Time = 0.12860631942749023
# 100% 10/10 [00:03<00:00,  2.79it/s]
# 2026-02-18 23:43:55,283 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:43:55,283 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:43:55,285 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:43:55,285 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:43:55,416 - ControlNet - INFO - ControlNet Hooked - Time = 0.1388711929321289
# 100% 10/10 [00:03<00:00,  2.78it/s]
# 2026-02-18 23:44:01,012 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:44:01,013 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:44:01,015 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:44:01,015 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:44:01,168 - ControlNet - INFO - ControlNet Hooked - Time = 0.16189360618591309
# 100% 10/10 [00:03<00:00,  2.76it/s]
# 2026-02-18 23:44:06,678 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:44:06,678 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:44:06,680 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:44:06,681 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:44:06,809 - ControlNet - INFO - ControlNet Hooked - Time = 0.13422846794128418
# 100% 10/10 [00:03<00:00,  2.75it/s]
# 2026-02-18 23:44:12,470 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:44:12,470 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:44:12,473 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:44:12,473 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:44:12,619 - ControlNet - INFO - ControlNet Hooked - Time = 0.1540365219116211
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:44:18,213 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:44:18,213 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:44:18,215 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:44:18,215 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:44:18,352 - ControlNet - INFO - ControlNet Hooked - Time = 0.14268231391906738
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:44:23,910 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:44:23,910 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:44:23,912 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:44:23,912 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:44:24,035 - ControlNet - INFO - ControlNet Hooked - Time = 0.12857460975646973
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:44:29,571 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:44:29,571 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:44:29,573 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:44:29,573 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:44:29,697 - ControlNet - INFO - ControlNet Hooked - Time = 0.12893223762512207
# 100% 10/10 [00:03<00:00,  2.74it/s]
# 2026-02-18 23:44:35,212 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:44:35,213 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:44:35,215 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:44:35,215 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:44:35,342 - ControlNet - INFO - ControlNet Hooked - Time = 0.13298606872558594
# 100% 10/10 [00:03<00:00,  2.73it/s]
# 2026-02-18 23:44:41,004 - ControlNet - INFO - unit_separate = False, style_align = False
# 2026-02-18 23:44:41,005 - ControlNet - INFO - Loading model from cache: control_v11p_sd15_softedge [a8575a2a]
# 2026-02-18 23:44:41,007 - ControlNet - INFO - Using preprocessor: softedge_pidinet
# 2026-02-18 23:44:41,008 - ControlNet - INFO - preprocessor resolution = 512
# 2026-02-18 23:44:41,154 - ControlNet - INFO - ControlNet Hooked - Time = 0.1546156406402588
# 100% 10/10 [00:03<00:00,  2.74it/s]
# Interrupted with signal 2 in <frame at 0x7b5f4ed143c0, file '/usr/lib/python3.12/threading.py', line 359, code wait>
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/webui.py", line 162, in <module>
#     webui()
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/webui.py", line 126, in webui
#     server_command = shared.state.wait_for_server_command(timeout=5)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/shared_state.py", line 63, in wait_for_server_command
#     if self._server_command_signal.wait(timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/threading.py", line 655, in wait
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/threading.py", line 359, in wait
#     gotit = waiter.acquire(True, timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/initialize_util.py", line 164, in sigint_handler
#     print(f'Interrupted with signal {sig} in {frame}')
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/initialize_util.py", line 164, in sigint_handler
#     print(f'Interrupted with signal {sig} in {frame}')
# RuntimeError: reentrant call inside <_io.BufferedWriter name='<stdout>'>
# Killing tunnel 127.0.0.1:7860 <> https://772a081bc3de25cb06.gradio.live
# sys:1: DeprecationWarning: builtin type swigvarlink has no __module__ attribute

# %%
import subprocess

import os
import subprocess
import glob

# --- CONFIGURACIÓN ---
input_folder = "/content/output_frames_v2"
output_video = "/content/video_caricatura_final.mp4"
fps = 15
# ---------------------

# 1. Verificar qué hay en la carpeta
files = sorted([f for f in os.listdir(input_folder) if f.endswith('.png')])

if len(files) == 0:
    print("❌ ERROR: La carpeta 'output_frames' está VACÍA.")
    print("Posibles causas:")
    print("1. No le diste a 'Generate' en la interfaz.")
    print("2. La ruta de salida en la interfaz no era exactamente '/content/output_frames'.")
    print("3. Stable Diffusion creó una subcarpeta (ej. una carpeta con la fecha dentro).")
    # Intentar buscar en subcarpetas
    all_files = glob.glob(f"{input_folder}/**/*.png", recursive=True)
    if len(all_files) > 0:
        print(f"⚠️ ¡OJO! Encontré {len(all_files)} imágenes en subcarpetas. Moviéndolas...")
        import shutil
        for i, f in enumerate(sorted(all_files)):
            shutil.move(f, os.path.join(input_folder, f"reparado_{i:05d}.png"))
        files = sorted([f for f in os.listdir(input_folder) if f.endswith('.png')])
        print("✅ Imágenes movidas y renombradas. Reintentando...")
    else:
        print("Solución: Revisa la carpeta en el menú de la izquierda.")
else:
    print(f"✅ Se encontraron {len(files)} imágenes. (Ejemplo: {files[0]})")

    # 2. Renombrar temporalmente para asegurar que ffmpeg las entienda
    # Esto soluciona si se llaman '00001.png' en vez de 'frame_00001.png'
    print("🔄 Preparando secuencia...")
    for i, filename in enumerate(files):
        src = os.path.join(input_folder, filename)
        dst = os.path.join(input_folder, f"secuencia_{i:05d}.png")
        os.rename(src, dst)

    # 3. Crear el video
    print("🎬 Renderizando video...")
    cmd = [
        'ffmpeg',
        '-y', # Sobreescribir si existe
        '-framerate', str(fps),
        '-i', f'{input_folder}/secuencia_%05d.png',
        '-c:v', 'libx264',
        '-pix_fmt', 'yuv420p',
        output_video
    ]

    subprocess.run(cmd)

    if os.path.exists(output_video) and os.path.getsize(output_video) > 1000:
        print(f"\n🎉 ¡ÉXITO TOTAL! Video creado: {output_video}")
        print("👉 Ahora sí, dale clic derecho a 'video_caricatura_final.mp4' y descárgalo.")
    else:
        print("\n❌ Algo falló en la creación del video. Revisa los logs.")
# Out:
# ✅ Se encontraron 148 imágenes. (Ejemplo: 00000-frame_00001.png)
# 🔄 Preparando secuencia...
# 🎬 Renderizando video...
#
# 🎉 ¡ÉXITO TOTAL! Video creado: /content/video_caricatura_final.mp4
# 👉 Ahora sí, dale clic derecho a 'video_caricatura_final.mp4' y descárgalo.

# %%
import os
import subprocess

# --- CONFIGURACIÓN ---
video_path = "/content/short10sec.mp4"  # <--- PEGA AQUÍ LA RUTA QUE COPIASTE (Mantén las comillas)
output_folder = "/content/input_frames"
# ---------------------

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Extraer imágenes (reducimos a 15 fps para estilo anime y ahorrar tiempo)
cmd = f"ffmpeg -i {video_path} -vf fps=15 {output_folder}/frame_%05d.png"
subprocess.run(cmd, shell=True)
print(f"✅ Listo! Frames guardados en: {output_folder}")
# Out:
# ✅ Listo! Frames guardados en: /content/input_frames
